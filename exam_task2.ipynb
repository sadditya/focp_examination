# %%
## How I Work Best in Programming

### My Learning Style and Tools

I believe I work best in programming when I use **simple tools** and follow a *step-by-step learning process*.  
My main tools are **Python**, *Jupyter Notebook*, and **Visual Studio Code**, because they help me write, test, and understand code clearly.

#### My Ideal Working Environment

- A quiet room with minimal noise  
- A comfortable desk and chair  
- A good internet connection  
- Clear lecture notes and examples  

I learn best by **practising regularly** and breaking big problems into *small tasks*.  
When I make mistakes, I treat them as **learning opportunities**, which helps me grow confident and motivated.
